# %%
import pymongo
import pprint

# %%
client = pymongo.MongoClient('mongodb://analytics-student:analytics-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')

# %%
trips = client.citibike.trips

# %%
# Replace XXXX with your aggregation pipeline to answer the question:
# Citibike trips that start at station id 279 end most frequently at what station id?
pipeline = [
    {
        '$match' : {'start station id' : 279}
    },
    {
        '$group': {'_id' : {'endstationid': "$end station id"}, 'total': {'$sum': 1}}
    },
    {
        '$sort': {'total': -1}
    }
]

# %%
# print the results
for trip in trips.aggregate(pipeline):
    pprint.pprint(trip)
# Out:
# {'_id': {'endstationid': 279}, 'total': 137}
# {'_id': {'endstationid': 316}, 'total': 112}
# {'_id': {'endstationid': 259}, 'total': 104}
# {'_id': {'endstationid': 387}, 'total': 99}
# {'_id': {'endstationid': 224}, 'total': 86}
# {'_id': {'endstationid': 306}, 'total': 83}
# {'_id': {'endstationid': 268}, 'total': 80}
# {'_id': {'endstationid': 260}, 'total': 75}
# {'_id': {'endstationid': 308}, 'total': 73}
# {'_id': {'endstationid': 360}, 'total': 71}
# {'_id': {'endstationid': 3002}, 'total': 63}
# {'_id': {'endstationid': 361}, 'total': 57}
# {'_id': {'endstationid': 337}, 'total': 56}
# {'_id': {'endstationid': 487}, 'total': 55}
# {'_id': {'endstationid': 2009}, 'total': 54}
# {'_id': {'endstationid': 401}, 'total': 53}
# {'_id': {'endstationid': 307}, 'total': 52}
# {'_id': {'endstationid': 502}, 'total': 51}
# {'_id': {'endstationid': 376}, 'total': 51}
# {'_id': {'endstationid': 304}, 'total': 50}
# {'_id': {'endstationid': 501}, 'total': 47}
# {'_id': {'endstationid': 332}, 'total': 46}
# {'_id': {'endstationid': 232}, 'total': 43}
# {'_id': {'endstationid': 2010}, 'total': 43}
# {'_id': {'endstationid': 174}, 'total': 41}
# {'_id': {'endstationid': 291}, 'total': 39}
# {'_id': {'endstationid': 408}, 'total': 38}
# {'_id': {'endstationid': 329}, 'total': 37}
# {'_id': {'endstationid': 195}, 'total': 37}
# {'_id': {'endstationid': 511}, 'total': 36}
# {'_id': {'endstationid': 319}, 'total': 34}
# {'_id': {'endstationid': 415}, 'total': 34}
# {'_id': {'endstationid': 350}, 'total': 33}
# {'_id': {'endstationid': 264}, 'total': 33}
# {'_id': {'endstationid': 312}, 'total': 32}
# {'_id': {'endstationid': 531}, 'total': 32}
# {'_id': {'endstationid': 147}, 'total': 31}
# {'_id': {'endstationid': 151}, 'total': 30}
# {'_id': {'endstationid': 386}, 'total': 30}
# {'_id': {'endstationid': 327}, 'total': 30}
# {'_id': {'endstationid': 341}, 'total': 29}
# {'_id': {'endstationid': 426}, 'total': 29}
# {'_id': {'endstationid': 445}, 'total': 27}
# {'_id': {'endstationid': 152}, 'total': 26}
# {'_id': {'endstationid': 150}, 'total': 26}
# {'_id': {'endstationid': 320}, 'total': 26}
# {'_id': {'endstationid': 410}, 'total': 25}
# {'_id': {'endstationid': 394}, 'total': 25}
# {'_id': {'endstationid': 321}, 'total': 24}
# {'_id': {'endstationid': 428}, 'total': 24}
# {'_id': {'endstationid': 351}, 'total': 23}
# {'_id': {'endstationid': 476}, 'total': 23}
# {'_id': {'endstationid': 249}, 'total': 23}
# {'_id': {'endstationid': 257}, 'total': 23}
# {'_id': {'endstationid': 534}, 'total': 23}
# {'_id': {'endstationid': 433}, 'total': 23}
# {'_id': {'endstationid': 276}, 'total': 22}
# {'_id': {'endstationid': 485}, 'total': 22}
# {'_id': {'endstationid': 417}, 'total': 22}
# {'_id': {'endstationid': 315}, 'total': 22}
# {'_id': {'endstationid': 263}, 'total': 22}
# {'_id': {'endstationid': 504}, 'total': 21}
# {'_id': {'endstationid': 545}, 'total': 21}
# {'_id': {'endstationid': 295}, 'total': 21}
# {'_id': {'endstationid': 427}, 'total': 21}
# {'_id': {'endstationid': 296}, 'total': 20}
# {'_id': {'endstationid': 217}, 'total': 20}
# {'_id': {'endstationid': 455}, 'total': 20}
# {'_id': {'endstationid': 392}, 'total': 20}
# {'_id': {'endstationid': 432}, 'total': 20}
# {'_id': {'endstationid': 461}, 'total': 19}
# {'_id': {'endstationid': 301}, 'total': 19}
# {'_id': {'endstationid': 507}, 'total': 19}
# {'_id': {'endstationid': 356}, 'total': 19}
# {'_id': {'endstationid': 532}, 'total': 19}
# {'_id': {'endstationid': 2008}, 'total': 19}
# {'_id': {'endstationid': 355}, 'total': 18}
# {'_id': {'endstationid': 524}, 'total': 18}
# {'_id': {'endstationid': 303}, 'total': 18}
# {'_id': {'endstationid': 411}, 'total': 18}
# {'_id': {'endstationid': 3119}, 'total': 18}
# {'_id': {'endstationid': 340}, 'total': 18}
# {'_id': {'endstationid': 339}, 'total': 17}
# {'_id': {'endstationid': 519}, 'total': 17}
# {'_id': {'endstationid': 317}, 'total': 17}
# {'_id': {'endstationid': 82}, 'total': 16}
# {'_id': {'endstationid': 297}, 'total': 16}
# {'_id': {'endstationid': 79}, 'total': 16}
# {'_id': {'endstationid': 309}, 'total': 16}
# {'_id': {'endstationid': 516}, 'total': 15}
# {'_id': {'endstationid': 293}, 'total': 15}
# {'_id': {'endstationid': 331}, 'total': 15}
# {'_id': {'endstationid': 229}, 'total': 15}
# {'_id': {'endstationid': 363}, 'total': 15}
# {'_id': {'endstationid': 393}, 'total': 15}
# {'_id': {'endstationid': 460}, 'total': 15}
# {'_id': {'endstationid': 2004}, 'total': 14}
# {'_id': {'endstationid': 330}, 'total': 14}
# {'_id': {'endstationid': 349}, 'total': 13}
# {'_id': {'endstationid': 285}, 'total': 13}
# {'_id': {'endstationid': 438}, 'total': 13}
# {'_id': {'endstationid': 302}, 'total': 12}
# {'_id': {'endstationid': 518}, 'total': 12}
# {'_id': {'endstationid': 146}, 'total': 12}
# {'_id': {'endstationid': 473}, 'total': 12}
# {'_id': {'endstationid': 472}, 'total': 12}
# {'_id': {'endstationid': 322}, 'total': 12}
# {'_id': {'endstationid': 265}, 'total': 12}
# {'_id': {'endstationid': 250}, 'total': 12}
# {'_id': {'endstationid': 382}, 'total': 11}
# {'_id': {'endstationid': 375}, 'total': 11}
# {'_id': {'endstationid': 412}, 'total': 11}
# {'_id': {'endstationid': 2012}, 'total': 11}
# {'_id': {'endstationid': 400}, 'total': 10}
# {'_id': {'endstationid': 237}, 'total': 10}
# {'_id': {'endstationid': 2003}, 'total': 10}
# {'_id': {'endstationid': 497}, 'total': 10}
# {'_id': {'endstationid': 527}, 'total': 10}
# {'_id': {'endstationid': 348}, 'total': 9}
# {'_id': {'endstationid': 347}, 'total': 9}
# {'_id': {'endstationid': 251}, 'total': 8}
# {'_id': {'endstationid': 459}, 'total': 8}
# {'_id': {'endstationid': 326}, 'total': 8}
# {'_id': {'endstationid': 236}, 'total': 8}
# {'_id': {'endstationid': 377}, 'total': 8}
# {'_id': {'endstationid': 323}, 'total': 8}
# {'_id': {'endstationid': 3104}, 'total': 8}
# {'_id': {'endstationid': 280}, 'total': 8}
# {'_id': {'endstationid': 475}, 'total': 8}
# {'_id': {'endstationid': 161}, 'total': 8}
# {'_id': {'endstationid': 128}, 'total': 8}
# {'_id': {'endstationid': 328}, 'total': 7}
# {'_id': {'endstationid': 167}, 'total': 7}
# {'_id': {'endstationid': 311}, 'total': 7}
# {'_id': {'endstationid': 405}, 'total': 7}
# {'_id': {'endstationid': 493}, 'total': 7}
# {'_id': {'endstationid': 278}, 'total': 7}
# {'_id': {'endstationid': 414}, 'total': 6}
# {'_id': {'endstationid': 407}, 'total': 6}
# {'_id': {'endstationid': 83}, 'total': 6}
# {'_id': {'endstationid': 440}, 'total': 6}
# {'_id': {'endstationid': 225}, 'total': 6}
# {'_id': {'endstationid': 439}, 'total': 6}
# {'_id': {'endstationid': 430}, 'total': 6}
# {'_id': {'endstationid': 3074}, 'total': 5}
# {'_id': {'endstationid': 539}, 'total': 5}
# {'_id': {'endstationid': 153}, 'total': 5}
# {'_id': {'endstationid': 368}, 'total': 5}
# {'_id': {'endstationid': 402}, 'total': 5}
# {'_id': {'endstationid': 253}, 'total': 5}
# {'_id': {'endstationid': 468}, 'total': 5}
# {'_id': {'endstationid': 168}, 'total': 5}
# {'_id': {'endstationid': 483}, 'total': 5}
# {'_id': {'endstationid': 346}, 'total': 5}
# {'_id': {'endstationid': 160}, 'total': 5}
# {'_id': {'endstationid': 266}, 'total': 5}
# {'_id': {'endstationid': 247}, 'total': 5}
# {'_id': {'endstationid': 491}, 'total': 5}
# {'_id': {'endstationid': 467}, 'total': 4}
# {'_id': {'endstationid': 358}, 'total': 4}
# {'_id': {'endstationid': 406}, 'total': 4}
# {'_id': {'endstationid': 469}, 'total': 4}
# {'_id': {'endstationid': 3058}, 'total': 4}
# {'_id': {'endstationid': 528}, 'total': 4}
# {'_id': {'endstationid': 536}, 'total': 4}
# {'_id': {'endstationid': 540}, 'total': 4}
# {'_id': {'endstationid': 380}, 'total': 4}
# {'_id': {'endstationid': 383}, 'total': 4}
# {'_id': {'endstationid': 462}, 'total': 4}
# {'_id': {'endstationid': 127}, 'total': 4}
# {'_id': {'endstationid': 2000}, 'total': 4}
# {'_id': {'endstationid': 525}, 'total': 4}
# {'_id': {'endstationid': 248}, 'total': 3}
# {'_id': {'endstationid': 238}, 'total': 3}
# {'_id': {'endstationid': 3093}, 'total': 3}
# {'_id': {'endstationid': 523}, 'total': 3}
# {'_id': {'endstationid': 216}, 'total': 3}
# {'_id': {'endstationid': 310}, 'total': 3}
# {'_id': {'endstationid': 2022}, 'total': 3}
# {'_id': {'endstationid': 454}, 'total': 3}
# {'_id': {'endstationid': 116}, 'total': 3}
# {'_id': {'endstationid': 403}, 'total': 3}
# {'_id': {'endstationid': 521}, 'total': 3}
# {'_id': {'endstationid': 481}, 'total': 3}
# {'_id': {'endstationid': 444}, 'total': 3}
# {'_id': {'endstationid': 494}, 'total': 3}
# {'_id': {'endstationid': 3105}, 'total': 3}
# {'_id': {'endstationid': 3142}, 'total': 3}
# {'_id': {'endstationid': 284}, 'total': 3}
# {'_id': {'endstationid': 391}, 'total': 3}
# {'_id': {'endstationid': 3055}, 'total': 3}
# {'_id': {'endstationid': 486}, 'total': 3}
# {'_id': {'endstationid': 336}, 'total': 3}
# {'_id': {'endstationid': 453}, 'total': 3}
# {'_id': {'endstationid': 435}, 'total': 3}
# {'_id': {'endstationid': 384}, 'total': 2}
# {'_id': {'endstationid': 3159}, 'total': 2}
# {'_id': {'endstationid': 508}, 'total': 2}
# {'_id': {'endstationid': 357}, 'total': 2}
# {'_id': {'endstationid': 3173}, 'total': 2}
# {'_id': {'endstationid': 3148}, 'total': 2}
# {'_id': {'endstationid': 465}, 'total': 2}
# {'_id': {'endstationid': 274}, 'total': 2}
# {'_id': {'endstationid': 369}, 'total': 2}
# {'_id': {'endstationid': 482}, 'total': 2}
# {'_id': {'endstationid': 546}, 'total': 2}
# {'_id': {'endstationid': 416}, 'total': 2}
# {'_id': {'endstationid': 526}, 'total': 2}
# {'_id': {'endstationid': 3140}, 'total': 2}
# {'_id': {'endstationid': 3242}, 'total': 2}
# {'_id': {'endstationid': 252}, 'total': 2}
# {'_id': {'endstationid': 3064}, 'total': 2}
# {'_id': {'endstationid': 517}, 'total': 2}
# {'_id': {'endstationid': 503}, 'total': 2}
# {'_id': {'endstationid': 496}, 'total': 2}
# {'_id': {'endstationid': 514}, 'total': 2}
# {'_id': {'endstationid': 3016}, 'total': 2}
# {'_id': {'endstationid': 2002}, 'total': 2}
# {'_id': {'endstationid': 474}, 'total': 2}
# {'_id': {'endstationid': 212}, 'total': 2}
# {'_id': {'endstationid': 3135}, 'total': 2}
# {'_id': {'endstationid': 470}, 'total': 2}
# {'_id': {'endstationid': 3103}, 'total': 2}
# {'_id': {'endstationid': 389}, 'total': 2}
# {'_id': {'endstationid': 3147}, 'total': 2}
# {'_id': {'endstationid': 537}, 'total': 2}
# {'_id': {'endstationid': 492}, 'total': 1}
# {'_id': {'endstationid': 533}, 'total': 1}
# {'_id': {'endstationid': 3171}, 'total': 1}
# {'_id': {'endstationid': 3144}, 'total': 1}
# {'_id': {'endstationid': 281}, 'total': 1}
# {'_id': {'endstationid': 434}, 'total': 1}
# {'_id': {'endstationid': 3113}, 'total': 1}
# {'_id': {'endstationid': 342}, 'total': 1}
# {'_id': {'endstationid': 522}, 'total': 1}
# {'_id': {'endstationid': 480}, 'total': 1}
# {'_id': {'endstationid': 449}, 'total': 1}
# {'_id': {'endstationid': 242}, 'total': 1}
# {'_id': {'endstationid': 282}, 'total': 1}
# {'_id': {'endstationid': 3155}, 'total': 1}
# {'_id': {'endstationid': 509}, 'total': 1}
# {'_id': {'endstationid': 373}, 'total': 1}
# {'_id': {'endstationid': 456}, 'total': 1}
# {'_id': {'endstationid': 458}, 'total': 1}
# {'_id': {'endstationid': 3052}, 'total': 1}
# {'_id': {'endstationid': 3166}, 'total': 1}
# {'_id': {'endstationid': 239}, 'total': 1}
# {'_id': {'endstationid': 3237}, 'total': 1}
# {'_id': {'endstationid': 385}, 'total': 1}
# {'_id': {'endstationid': 244}, 'total': 1}
# {'_id': {'endstationid': 275}, 'total': 1}
# {'_id': {'endstationid': 3244}, 'total': 1}
# {'_id': {'endstationid': 245}, 'total': 1}
# {'_id': {'endstationid': 254}, 'total': 1}
# {'_id': {'endstationid': 243}, 'total': 1}
# {'_id': {'endstationid': 379}, 'total': 1}
# {'_id': {'endstationid': 300}, 'total': 1}
# {'_id': {'endstationid': 262}, 'total': 1}
# {'_id': {'endstationid': 359}, 'total': 1}
# {'_id': {'endstationid': 2006}, 'total': 1}
# {'_id': {'endstationid': 3017}, 'total': 1}
# {'_id': {'endstationid': 3223}, 'total': 1}
# {'_id': {'endstationid': 484}, 'total': 1}
# {'_id': {'endstationid': 3154}, 'total': 1}
# {'_id': {'endstationid': 3229}, 'total': 1}
# {'_id': {'endstationid': 463}, 'total': 1}
# {'_id': {'endstationid': 325}, 'total': 1}
# {'_id': {'endstationid': 3141}, 'total': 1}
# {'_id': {'endstationid': 3222}, 'total': 1}
# {'_id': {'endstationid': 3059}, 'total': 1}
# {'_id': {'endstationid': 515}, 'total': 1}
# {'_id': {'endstationid': 298}, 'total': 1}
# {'_id': {'endstationid': 420}, 'total': 1}
# {'_id': {'endstationid': 3224}, 'total': 1}
# {'_id': {'endstationid': 3158}, 'total': 1}
# {'_id': {'endstationid': 436}, 'total': 1}
# {'_id': {'endstationid': 3088}, 'total': 1}
# {'_id': {'endstationid': 335}, 'total': 1}
# {'_id': {'endstationid': 3122}, 'total': 1}
# {'_id': {'endstationid': 223}, 'total': 1}
